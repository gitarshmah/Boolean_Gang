# %% [markdown]
# <a href="https://colab.research.google.com/github/gitarshmah/Boolean_Gang/blob/ML-Framework/INFY_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nsepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nsepy in /usr/local/lib/python3.8/dist-packages (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from nsepy) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from nsepy) (4.9.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nsepy) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from nsepy) (2.25.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nsepy) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (4.0.0)

# %%
import nsepy as nse
import datetime
from datetime import date as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly as py

# %%
comp_symbol = 'INFY'

# %% [markdown]
# ## Load Dataset

# %%
today = dt.today()
two_yrs = today - datetime.timedelta(days = int(2.5*365))

# %%
#Load dataset
stock = nse.get_history(symbol=comp_symbol, index = False, start=two_yrs, end=today)

# %%
stock
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2020-08-12   INFY     EQ      948.45   948.00   958.80   942.20   952.85
# 2020-08-13   INFY     EQ      954.95   954.80   968.50   948.25   952.30
# 2020-08-14   INFY     EQ      951.20   955.85   963.00   952.05   954.50
# 2020-08-17   INFY     EQ      953.60   954.10   972.45   954.10   958.30
# 2020-08-18   INFY     EQ      957.50   963.90   969.20   958.70   967.10
# ...           ...    ...         ...      ...      ...      ...      ...
# 2023-02-03   INFY     EQ     1583.75  1597.50  1604.65  1573.00  1595.65
# 2023-02-06   INFY     EQ     1599.40  1598.00  1598.00  1561.60  1565.00
# 2023-02-07   INFY     EQ     1569.85  1569.00  1576.05  1555.10  1563.10
# 2023-02-08   INFY     EQ     1562.40  1565.50  1603.00  1565.50  1590.00
# 2023-02-09   INFY     EQ     1590.50  1596.20  1619.75  1586.05  1617.00
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2020-08-12   954.95   950.21  6908732  6.564723e+14   89286
# 2020-08-13   951.20   956.51  5097705  4.876026e+14   87144
# 2020-08-14   953.60   957.20  4663873  4.464257e+14   88402
# 2020-08-17   957.50   962.38  9008716  8.669769e+14  140270
# 2020-08-18   967.55   964.28  6142171  5.922744e+14  119041
# ...             ...      ...      ...           ...     ...
# 2023-02-03  1599.40  1593.62  7040194  1.121937e+15  191136
# 2023-02-06  1569.85  1570.72  4570612  7.179133e+14  154367
# 2023-02-07  1562.40  1567.15  4336238  6.795552e+14  122034
# 2023-02-08  1590.50  1594.11  7983338  1.272634e+15  193218
# 2023-02-09  1617.00  1605.30  6904911  1.108446e+15  187813
#
#             Deliverable Volume  %Deliverble
# Date
# 2020-08-12             2560388       0.3706
# 2020-08-13             1882537       0.3693
# 2020-08-14             1975922       0.4237
# 2020-08-17             2894495       0.3213
# 2020-08-18             2806845       0.4570
# ...                        ...          ...
# 2023-02-03             4844776       0.6882
# 2023-02-06             2890524       0.6324
# 2023-02-07             3070813       0.7082
# 2023-02-08             5949971       0.7453
# 2023-02-09             5171300       0.7489
#
# [623 rows x 14 columns]

# %%
df = stock

# %% [markdown]
# ## Analysis

# %%
stock['MA60'] = df['Close'].rolling(window=45, min_periods=0).mean()
stock['MA45'] = df['Close'].rolling(window=15, min_periods=0).mean()
stock['MA90'] = df['Close'].rolling(window=90, min_periods=0).mean()

# %%
fig = make_subplots(rows=2, cols = 1, shared_xaxes=True, subplot_titles=[comp_symbol, 'Volume'], vertical_spacing=0.10, row_heights=[0.7, 0.3]) #vertical_spacing, row_width

fig.add_trace(go.Candlestick(x=df.index, open=stock['Open'], close=stock['Close'], high=stock['High'], low=stock['Low'], name=comp_symbol) , row=1, col=1 )

fig.add_trace(go.Scatter(x=df.index, y=stock['MA90'], marker_color='lightgrey', name='MA90'), row=1, col=1)

fig.add_trace(go.Scatter(x=df
]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((0,1))

# df_train = df

# Test = 45 days
df_test = df[-pred_days:]
df_train = df[:-pred_days]
df_test.shape, df_train.shape

# Train-Val split (70-30)
trainSize = int(len(df_train) * 0.8)
df_val = df_train[trainSize:]
df_train = df_train[:trainSize]

# Create Train-Val 
train_set = df_train.values
val_set = df_val.values

train_set = scaler.fit_transform(np.array(train_set).reshape(-1,1))
val_set = scaler.fit_transform(np.array(val_set).reshape(-1,1))

def data_prep(dataset, timestep):
  X, y = [], []
  for i in range(timestep, dataset.shape[0]):
    X.append(dataset[i-timestep:i, 0])
    y.append(dataset[i,0])
  
  return (np.array(X), np.array(y))


(x_train, y_train) = data_prep(train_set, timestep)
(x_val, y_val) = data_prep(val_set, timestep)

x_train = np.reshape(x_train, newshape = (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, newshape = (x_val.shape[0], x_val.shape[1], 1))

  # return (x_train, y_train), (x_val, y_val), scaler

# %% [markdown]
# ## Define the model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import Huber

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(1))

opt = Adam(learning_rate = 0.001)
huber = Huber()
model.compile(optimizer = opt, loss=huber, metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 90, 50)            10400
#
#  dropout (Dropout)           (None, 90, 50)            0
#
#  lstm_1 (LSTM)               (None, 90, 50)            20200
#
#  dropout_1 (Dropout)         (None, 90, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
# Train the model
hist = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=2, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 12/12 - 3s - loss: 0.0057 - mae: 0.0824 - val_loss: 0.0213 - val_mae: 0.1844 - 3s/epoch - 245ms/step
# Epoch 2/100
# 12/12 - 1s - loss: 0.0053 - mae: 0.0808 - val_loss: 0.0199 - val_mae: 0.1774 - 1s/epoch - 121ms/step
# Epoch 3/100
# 12/12 - 1s - loss: 0.0049 - mae: 0.0760 - val_loss: 0.0108 - val_mae: 0.1292 - 1s/epoch - 120ms/step
# Epoch 4/100
# 12/12 - 1s - loss: 0.0045 - mae: 0.0733 - val_loss: 0.0102 - val_mae: 0.1256 - 1s/epoch - 120ms/step
# Epoch 5/100
# 12/12 - 1s - loss: 0.0045 - mae: 0.0743 - val_loss: 0.0121 - val_mae: 0.1371 - 1s/epoch - 119ms/step
# Epoch 6/100
# 12/12 - 1s - loss: 0.0047 - mae: 0.0732 - val_loss: 0.0085 - val_mae: 0.1164 - 1s/epoch - 118ms/step
# Epoch 7/100
# 12/12 - 1s - loss: 0.0049 - mae: 0.0751 - val_loss: 0.0068 - val_mae: 0.1042 - 1s/epoch - 120ms/step
# Epoch 8/100
# 12/12 - 2s - loss: 0.0056 - mae: 0.0822 - val_loss: 0.0104 - val_mae: 0.1272 - 2s/epoch - 180ms/step
# Epoch 9/100
# 12/12 - 2s - loss: 0.0047 - mae: 0.0761 - val_loss: 0.0147 - val_mae: 0.1509 - 2s/epoch - 147ms/step
# Epoch 10/100
# 12/12 - 1s - loss: 0.0046 - mae: 0.0742 - val_loss: 0.0166 - val_mae: 0.1615 - 1s/epoch - 119ms/step
# Epoch 11/100
# 12/12 - 1s - loss: 0.0047 - mae: 0.0746 - val_loss: 0.0206 - val_mae: 0.1807 - 1s/epoch - 120ms/step
# Epoch 12/100
# 12/12 - 1s - loss: 0.0051 - mae: 0.0780 - val_loss: 0.0140 - val_mae: 0.1474 - 1s/epoch - 119ms/step
# Epoch 13/100
# 12/12 - 1s - loss: 0.0040 - mae: 0.0695 - val_loss: 0.0090 - val_mae: 0.1197 - 1s/epoch - 119ms/step
# Epoch 14/100
# 12/12 - 1s - loss: 0.0038 - mae: 0.0676 - val_loss: 0.0084 - val_mae: 0.1160 - 1s/epoch - 119ms/step
# Epoch 15/100
# 12/12 - 1s - loss: 0.0039 - mae: 0.0683 - val_loss: 0.0107 - val_mae: 0.1297 - 1s/epoch - 118ms/step
# Epoch 16/100
# 12/12 - 2s - loss: 0.0041 - mae: 0.0694 - val_loss: 0.0094 - val_mae: 0.1226 - 2s/epoch - 181ms/step
# Epoch 17/100
# 12/12 - 2s - loss: 0.0042 - mae: 0.0703 - val_loss: 0.0105 - val_mae: 0.1290 - 2s/epoch - 145ms/step
# Epoch 18/100
# 12/12 - 1s - loss: 0.0040 - mae: 0.0705 - val_loss: 0.0094 - val_mae: 0.1227 - 1s/epoch - 118ms/step
# Epoch 19/100
# 12/12 - 1s - loss: 0.0038 - mae: 0.0699 - val_loss: 0.0120 - val_mae: 0.1374 - 1s/epoch - 118ms/step
# Epoch 20/100
# 12/12 - 1s - loss: 0.0036 - mae: 0.0667 - val_loss: 0.0118 - val_mae: 0.1362 - 1s/epoch - 118ms/step
# Epoch 21/100
# 12/12 - 1s - loss: 0.0042 - mae: 0.0714 - val_loss: 0.0133 - val_mae: 0.1438 - 1s/epoch - 120ms/step
# Epoch 22/100
# 12/12 - 1s - loss: 0.0041 - mae: 0.0701 - val_loss: 0.0082 - val_mae: 0.1157 - 1s/epoch - 122ms/step
# Epoch 23/100
# 12/12 - 2s - loss: 0.0041 - mae: 0.0680 - val_loss: 0.0077 - val_mae: 0.1119 - 2s/epoch - 138ms/step
# Epoch 24/100
# 12/12 - 3s - loss: 0.0038 - mae: 0.0678 - val_loss: 0.0071 - val_mae: 0.1071 - 3s/epoch - 230ms/step
# Epoch 25/100
# 12/12 - 2s - loss: 0.0045 - mae: 0.0740 - val_loss: 0.0069 - val_mae: 0.1054 - 2s/epoch - 175ms/step
# Epoch 26/100
# 12/12 - 1s - loss: 0.0037 - mae: 0.0650 - val_loss: 0.0077 - val_mae: 0.1117 - 1s/epoch - 120ms/step
# Epoch 27/100
# 12/12 - 1s - loss: 0.0037 - mae: 0.0665 - val_loss: 0.0093 - val_mae: 0.1223 - 1s/epoch - 118ms/step
# Epoch 28/100
# 12/12 - 1s - loss: 0.0042 - mae: 0.0699 - val_loss: 0.0093 - val_mae: 0.1221 - 1s/epoch - 122ms/step
# Epoch 29/100
# 12/12 - 1s - loss: 0.0035 - mae: 0.0639 - val_loss: 0.0073 - val_mae: 0.1085 - 1s/epoch - 118ms/step
# Epoch 30/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0626 - val_loss: 0.0110 - val_mae: 0.1314 - 1s/epoch - 121ms/step
# Epoch 31/100
# 12/12 - 1s - loss: 0.0038 - mae: 0.0680 - val_loss: 0.0093 - val_mae: 0.1223 - 1s/epoch - 118ms/step
# Epoch 32/100
# 12/12 - 2s - loss: 0.0038 - mae: 0.0671 - val_loss: 0.0081 - val_mae: 0.1143 - 2s/epoch - 159ms/step
# Epoch 33/100
# 12/12 - 2s - loss: 0.0035 - mae: 0.0649 - val_loss: 0.0082 - val_mae: 0.1153 - 2s/epoch - 166ms/step
# Epoch 34/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0627 - val_loss: 0.0076 - val_mae: 0.1105 - 1s/epoch - 119ms/step
# Epoch 35/100
# 12/12 - 1s - loss: 0.0032 - mae: 0.0618 - val_loss: 0.0069 - val_mae: 0.1050 - 1s/epoch - 121ms/step
# Epoch 36/100
# 12/12 - 1s - loss: 0.0036 - mae: 0.0659 - val_loss: 0.0092 - val_mae: 0.1215 - 1s/epoch - 119ms/step
# Epoch 37/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0625 - val_loss: 0.0116 - val_mae: 0.1351 - 1s/epoch - 121ms/step
# Epoch 38/100
# 12/12 - 1s - loss: 0.0039 - mae: 0.0672 - val_loss: 0.0103 - val_mae: 0.1281 - 1s/epoch - 119ms/step
# Epoch 39/100
# 12/12 - 1s - loss: 0.0041 - mae: 0.0677 - val_loss: 0.0062 - val_mae: 0.0980 - 1s/epoch - 119ms/step
# Epoch 40/100
# 12/12 - 2s - loss: 0.0033 - mae: 0.0631 - val_loss: 0.0063 - val_mae: 0.0994 - 2s/epoch - 161ms/step
# Epoch 41/100
# 12/12 - 2s - loss: 0.0034 - mae: 0.0628 - val_loss: 0.0070 - val_mae: 0.1055 - 2s/epoch - 166ms/step
# Epoch 42/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0642 - val_loss: 0.0073 - val_mae: 0.1076 - 1s/epoch - 119ms/step
# Epoch 43/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0630 - val_loss: 0.0069 - val_mae: 0.1037 - 1s/epoch - 119ms/step
# Epoch 44/100
# 12/12 - 1s - loss: 0.0027 - mae: 0.0566 - val_loss: 0.0075 - val_mae: 0.1095 - 1s/epoch - 120ms/step
# Epoch 45/100
# 12/12 - 1s - loss: 0.0032 - mae: 0.0612 - val_loss: 0.0071 - val_mae: 0.1056 - 1s/epoch - 121ms/step
# Epoch 46/100
# 12/12 - 1s - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0064 - val_mae: 0.0999 - 1s/epoch - 119ms/step
# Epoch 47/100
# 12/12 - 1s - loss: 0.0031 - mae: 0.0602 - val_loss: 0.0069 - val_mae: 0.1035 - 1s/epoch - 120ms/step
# Epoch 48/100
# 12/12 - 2s - loss: 0.0031 - mae: 0.0610 - val_loss: 0.0079 - val_mae: 0.1119 - 2s/epoch - 165ms/step
# Epoch 49/100
# 12/12 - 2s - loss: 0.0031 - mae: 0.0607 - val_loss: 0.0080 - val_mae: 0.1125 - 2s/epoch - 161ms/step
# Epoch 50/100
# 12/12 - 1s - loss: 0.0028 - mae: 0.0585 - val_loss: 0.0069 - val_mae: 0.1027 - 1s/epoch - 119ms/step
# Epoch 51/100
# 12/12 - 1s - loss: 0.0032 - mae: 0.0595 - val_loss: 0.0062 - val_mae: 0.0968 - 1s/epoch - 119ms/step
# Epoch 52/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0629 - val_loss: 0.0063 - val_mae: 0.0983 - 1s/epoch - 119ms/step
# Epoch 53/100
# 12/12 - 1s - loss: 0.0037 - mae: 0.0675 - val_loss: 0.0062 - val_mae: 0.0973 - 1s/epoch - 120ms/step
# Epoch 54/100
# 12/12 - 1s - loss: 0.0034 - mae: 0.0635 - val_loss: 0.0084 - val_mae: 0.1155 - 1s/epoch - 122ms/step
# Epoch 55/100
# 12/12 - 1s - loss: 0.0031 - mae: 0.0614 - val_loss: 0.0082 - val_mae: 0.1137 - 1s/epoch - 122ms/step
# Epoch 56/100
# 12/12 - 2s - loss: 0.0032 - mae: 0.0611 - val_loss: 0.0091 - val_mae: 0.1199 - 2s/epoch - 167ms/step
# Epoch 57/100
# 12/12 - 3s - loss: 0.0032 - mae: 0.0620 - val_loss: 0.0095 - val_mae: 0.1226 - 3s/epoch - 210ms/step
# Epoch 58/100
# 12/12 - 2s - loss: 0.0031 - mae: 0.0600 - val_loss: 0.0080 - val_mae: 0.1116 - 2s/epoch - 155ms/step
# Epoch 59/100
# 12/12 - 1s - loss: 0.0030 - mae: 0.0587 - val_loss: 0.0083 - val_mae: 0.1144 - 1s/epoch - 120ms/step
# Epoch 60/100
# 12/12 - 1s - loss: 0.0034 - mae: 0.0630 - val_loss: 0.0092 - val_mae: 0.1202 - 1s/epoch - 119ms/step
# Epoch 61/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0565 - val_loss: 0.0072 - val_mae: 0.1059 - 1s/epoch - 120ms/step
# Epoch 62/100
# 12/12 - 1s - loss: 0.0032 - mae: 0.0607 - val_loss: 0.0090 - val_mae: 0.1187 - 1s/epoch - 121ms/step
# Epoch 63/100
# 12/12 - 1s - loss: 0.0030 - mae: 0.0584 - val_loss: 0.0082 - val_mae: 0.1131 - 1s/epoch - 119ms/step
# Epoch 64/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0548 - val_loss: 0.0083 - val_mae: 0.1135 - 2s/epoch - 198ms/step
# Epoch 65/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0584 - val_loss: 0.0070 - val_mae: 0.1036 - 2s/epoch - 128ms/step
# Epoch 66/100
# 12/12 - 1s - loss: 0.0025 - mae: 0.0563 - val_loss: 0.0065 - val_mae: 0.0997 - 1s/epoch - 120ms/step
# Epoch 67/100
# 12/12 - 1s - loss: 0.0027 - mae: 0.0567 - val_loss: 0.0070 - val_mae: 0.1032 - 1s/epoch - 120ms/step
# Epoch 68/100
# 12/12 - 1s - loss: 0.0030 - mae: 0.0597 - val_loss: 0.0067 - val_mae: 0.1010 - 1s/epoch - 120ms/step
# Epoch 69/100
# 12/12 - 1s - loss: 0.0025 - mae: 0.0544 - val_loss: 0.0081 - val_mae: 0.1113 - 1s/epoch - 120ms/step
# Epoch 70/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0567 - val_loss: 0.0082 - val_mae: 0.1127 - 1s/epoch - 119ms/step
# Epoch 71/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0543 - val_loss: 0.0064 - val_mae: 0.0992 - 1s/epoch - 120ms/step
# Epoch 72/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0551 - val_loss: 0.0078 - val_mae: 0.1090 - 2s/epoch - 199ms/step
# Epoch 73/100
# 12/12 - 2s - loss: 0.0028 - mae: 0.0574 - val_loss: 0.0075 - val_mae: 0.1064 - 2s/epoch - 127ms/step
# Epoch 74/100
# 12/12 - 1s - loss: 0.0033 - mae: 0.0618 - val_loss: 0.0068 - val_mae: 0.1017 - 1s/epoch - 120ms/step
# Epoch 75/100
# 12/12 - 1s - loss: 0.0027 - mae: 0.0573 - val_loss: 0.0079 - val_mae: 0.1099 - 1s/epoch - 120ms/step
# Epoch 76/100
# 12/12 - 1s - loss: 0.0023 - mae: 0.0535 - val_loss: 0.0073 - val_mae: 0.1044 - 1s/epoch - 119ms/step
# Epoch 77/100
# 12/12 - 1s - loss: 0.0029 - mae: 0.0599 - val_loss: 0.0060 - val_mae: 0.0947 - 1s/epoch - 119ms/step
# Epoch 78/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0552 - val_loss: 0.0063 - val_mae: 0.0970 - 1s/epoch - 120ms/step
# Epoch 79/100
# 12/12 - 1s - loss: 0.0025 - mae: 0.0539 - val_loss: 0.0077 - val_mae: 0.1080 - 1s/epoch - 122ms/step
# Epoch 80/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0557 - val_loss: 0.0097 - val_mae: 0.1217 - 2s/epoch - 201ms/step
# Epoch 81/100
# 12/12 - 1s - loss: 0.0030 - mae: 0.0591 - val_loss: 0.0099 - val_mae: 0.1225 - 1s/epoch - 124ms/step
# Epoch 82/100
# 12/12 - 1s - loss: 0.0029 - mae: 0.0587 - val_loss: 0.0075 - val_mae: 0.1062 - 1s/epoch - 120ms/step
# Epoch 83/100
# 12/12 - 1s - loss: 0.0030 - mae: 0.0594 - val_loss: 0.0061 - val_mae: 0.0962 - 1s/epoch - 120ms/step
# Epoch 84/100
# 12/12 - 1s - loss: 0.0028 - mae: 0.0579 - val_loss: 0.0064 - val_mae: 0.0984 - 1s/epoch - 121ms/step
# Epoch 85/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0540 - val_loss: 0.0066 - val_mae: 0.1004 - 1s/epoch - 119ms/step
# Epoch 86/100
# 12/12 - 1s - loss: 0.0026 - mae: 0.0569 - val_loss: 0.0063 - val_mae: 0.0974 - 1s/epoch - 121ms/step
# Epoch 87/100
# 12/12 - 1s - loss: 0.0027 - mae: 0.0574 - val_loss: 0.0064 - val_mae: 0.0985 - 1s/epoch - 123ms/step
# Epoch 88/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0561 - val_loss: 0.0068 - val_mae: 0.1021 - 2s/epoch - 198ms/step
# Epoch 89/100
# 12/12 - 1s - loss: 0.0025 - mae: 0.0541 - val_loss: 0.0084 - val_mae: 0.1119 - 1s/epoch - 121ms/step
# Epoch 90/100
# 12/12 - 1s - loss: 0.0023 - mae: 0.0527 - val_loss: 0.0090 - val_mae: 0.1160 - 1s/epoch - 119ms/step
# Epoch 91/100
# 12/12 - 1s - loss: 0.0024 - mae: 0.0521 - val_loss: 0.0072 - val_mae: 0.1047 - 1s/epoch - 119ms/step
# Epoch 92/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0552 - val_loss: 0.0069 - val_mae: 0.1021 - 2s/epoch - 151ms/step
# Epoch 93/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0523 - val_loss: 0.0071 - val_mae: 0.1032 - 2s/epoch - 176ms/step
# Epoch 94/100
# 12/12 - 1s - loss: 0.0023 - mae: 0.0534 - val_loss: 0.0069 - val_mae: 0.1016 - 1s/epoch - 123ms/step
# Epoch 95/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0528 - val_loss: 0.0069 - val_mae: 0.1018 - 2s/epoch - 184ms/step
# Epoch 96/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0546 - val_loss: 0.0066 - val_mae: 0.1003 - 2s/epoch - 141ms/step
# Epoch 97/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0517 - val_loss: 0.0083 - val_mae: 0.1106 - 2s/epoch - 127ms/step
# Epoch 98/100
# 12/12 - 3s - loss: 0.0023 - mae: 0.0539 - val_loss: 0.0086 - val_mae: 0.1125 - 3s/epoch - 263ms/step
# Epoch 99/100
# 12/12 - 3s - loss: 0.0024 - mae: 0.0549 - val_loss: 0.0096 - val_mae: 0.1188 - 3s/epoch - 234ms/step
# Epoch 100/100
# 12/12 - 4s - loss: 0.0028 - mae: 0.0565 - val_loss: 0.0082 - val_mae: 0.1100 - 4s/epoch - 301ms/step

# %%
plt.figure(figsize = (12, 8))
plt.plot(hist.history['loss'][2:], label = "Training loss")
plt.plot(hist.history['val_loss'][2:], label = "Val loss")
plt.title("Loss analysis")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid("both")

# %% [markdown]
# ## Model Evaluation

# %%
train_pred = model.predict(x_train)
val_pred = model.predict(x_val)

train_pred = scaler.inverse_transform(train_pred)
val_pred = scaler.inverse_transform(val_pred)

train_set_temp = scaler.inverse_transform(train_set)
val_set_temp = scaler.inverse_transform(val_set)
# Out:
# 12/12 [==============================] - 2s 50ms/step
# 1/1 [==============================] - 0s 45ms/step

# %%
x1 = train_set_temp[-(train_pred.shape[0]):]
plt.figure(figsize = (15,5))
plt.plot(x1, color = 'black', label = 'Real prices')
plt.plot(train_pred, color='red', label='Predicted prices')
plt.legend()
plt.grid()

# %%
x2 = val_set_temp[-(val_pred.shape[0]):]
plt.figure(figsize = (15,5))
plt.plot(x2, color = 'black', label = 'Real prices')
plt.plot(val_pred, color='red', label='Predicted prices')
plt.legend()
plt.grid()

# %% [markdown]
# ## Prediction

# %%
train_dataset = pd.concat([df_train, df_val])

train_values = train_dataset.values

# %%
def prediction(timestep, inp):
  input = inp[-(timestep+pred_days):]

  input = scaler.fit_transform(np.array(input).reshape(-1,1))

  x_test = []
  for i in range(timestep, input.shape[0]):
    x_test.append(input[(i - timestep) : i , 0])
  x_test = np.array(x_test)

  x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

  return x_test, scaler

# %%
x_test, scaler = prediction(timestep, train_values)
y_pred = model.predict(x_test)
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 2/2 [==============================] - 0s 26ms/step

# %%
plt.figure(figsize=(15,5))

plt.plot(df_test.values, color='black', label='Real Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.grid()
plt.legend()
plt.title(f"Stock Price Predicted for {comp_symbol}")
plt.xlabel("Next Days")
plt.ylabel("Price (Rs/Share)")
# Out:
# Text(0, 0.5, 'Price (Rs/Share)')
