# %% [markdown]
# <a href="https://colab.research.google.com/github/gitarshmah/Boolean_Gang/blob/ML-Framework/ABBOTINDIA_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nsepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nsepy
#   Downloading nsepy-0.8.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from nsepy) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from nsepy) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from nsepy) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nsepy) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from nsepy) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nsepy) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->nsepy) (4.0.0)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py) ... done
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36085 sha256=9cefde61e5a5e19a87aa44fd05e920160fc3e79877ef4be8906688eb3d677b1a
#   Stored in directory: /root/.cache/pip/wheels/b9/2c/cb/d74199e422a1dbc20297d10cfff9c54d03e0b5c6694d49ccdd
# Successfully built nsepy
# Installing collected packages: nsepy
# Successfully installed nsepy-0.8

# %%
import nsepy as nse
import datetime
from datetime import date as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly as py

# %%
comp_symbol = 'ABBOTINDIA'

# %% [markdown]
# ## Load Dataset

# %%
today = dt.today()
two_yrs = today - datetime.timedelta(days = int(2.5*365))

# %%
#Load dataset
stock = nse.get_history(symbol=comp_symbol, index = False, start=two_yrs, end=today)

# %%
stock
# Out:
#                 Symbol Series  Prev Close      Open      High       Low  \
# Date
# 2020-08-12  ABBOTINDIA     EQ    16618.65  16618.65  16799.95  16256.55
# 2020-08-13  ABBOTINDIA     EQ    16683.05  16800.00  16872.50  16600.00
# 2020-08-14  ABBOTINDIA     EQ    16672.85  16674.00  16750.00  16257.45
# 2020-08-17  ABBOTINDIA     EQ    16468.90  16570.00  16830.00  16475.00
# 2020-08-18  ABBOTINDIA     EQ    16675.05  16800.00  16825.00  16560.00
# ...                ...    ...         ...       ...       ...       ...
# 2023-02-03  ABBOTINDIA     EQ    20480.30  20500.00  20925.30  20436.65
# 2023-02-06  ABBOTINDIA     EQ    20872.25  20872.05  20999.90  20650.00
# 2023-02-07  ABBOTINDIA     EQ    20869.75  20800.00  21059.90  20708.05
# 2023-02-08  ABBOTINDIA     EQ    20991.45  20980.00  21347.00  20831.10
# 2023-02-09  ABBOTINDIA     EQ    21278.25  21084.80  21593.85  20800.00
#
#                 Last     Close      VWAP  Volume      Turnover  Trades  \
# Date
# 2020-08-12  16640.00  16683.05  16602.32   13801  2.291287e+13    5597
# 2020-08-13  16700.00  16672.85  16713.42    9794  1.636913e+13    4359
# 2020-08-14  16460.05  16468.90  16585.99    9765  1.619622e+13    3758
# 2020-08-17  16685.05  16675.05  16673.21   10045  1.674824e+13    3979
# 2020-08-18  16570.00  16590.80  16688.01   10920  1.822331e+13    3805
# ...              ...       ...       ...     ...           ...     ...
# 2023-02-03  20800.00  20872.25  20738.61    7409  1.536523e+13    2921
# 2023-02-06  20825.05  20869.75  20829.66    4263  8.879685e+12    2160
# 2023-02-07  20920.00  20991.45  20867.40    5981  1.248079e+13    2858
# 2023-02-08  21323.95  21278.25  21112.77    6149  1.298224e+13    2841
# 2023-02-09  20845.00  20846.20  21160.54   12723  2.692255e+13    5159
#
#             Deliverable Volume  %Deliverble
# Date
# 2020-08-12                5194       0.3763
# 2020-08-13                4699       0.4798
# 2020-08-14                5666       0.5802
# 2020-08-17                4680       0.4659
# 2020-08-18                5882       0.5386
# ...                        ...          ...
# 2023-02-03                3095       0.4177
# 2023-02-06                1168       0.2740
# 2023-02-07                1246       0.2083
# 2023-02-08                2333       0.3794
# 2023-02-09                3124       0.2455
#
# [623 rows x 14 columns]

# %%
df = stock

# %% [markdown]
# ## Analysis

# %%
stock['MA60'] = df['Close'].rolling(window=45, min_periods=0).mean()
stock['MA45'] = df['Close'].rolling(window=15, min_periods=0).mean()
stock['MA90'] = df['Close'].rolling(window=90, min_periods=0).mean()

# %%
fig = make_subplots(rows=2, cols = 1, shared_xaxes=True, subplot_titles=[comp_symbol, 'Volume'], vertical_spacing=0.10, row_heights=[0.7, 0.3]) #vertical_spacing, row_width

fig.add_trace(go.Candlestick(x=df.index, open=stock['Open'], close=stock['Close'], high=stock['High'], low=stock['Low'], name=comp_symbol) , row=1, col=1 )

fig.add_trace(go.Scatter(x=df.index, y=stock['MA90'], marker_color='lightgrey', name='MA90'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.index, y=stock['MA60'], marker_color='black', name='MA60'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.index, y=stock['MA45'], marker_color='grey', name='MA45'), row=1, col=1)

fig.add_trace(go.Bar(x=df.index, y=stock['Volume'], marker_color='red', showlegend=False), row=2, col=1)

fig.update_layout(
    title= comp_symbol + ' historical price chart',
    xaxis_tickfont_size=12,
    yaxis=dict(
        title='Price (Rs/share)',
        titlefont_size=14,
        tickfont_size=12,
    ),
    autosize=False,
    width=1100,
    height=500,
    margin=dict(l=50, r=50, b=50, t=100, pad=3),
    paper_bgcolor='LightSteelBlue'
)
fig.update(layout_xaxis_rangeslider_visible=False)
fig.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="08bee921-19a8-492e-aa48-73a5a6251f5c" class="plotly-graph-div" style="height:500px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08bee921-19a8-492e-aa48-73a5a6251f5c")) {                    Plotly.newPlot(                        "08bee921-19a8-492e-aa48-73a5a6251f5c",                        [{"close":[16683.05,16672.85,16468.9,16675.05,16590.8,16866.5,16867.9,16840.25,16974.45,16898.65,16944.0,17065.1,16816.05,16377.1,16402.75,16390.0,16444.5,16541.95,16486.0,16723.0,16631.45,16526.1,16819.25,16516.15,16895.6,16525.1,16441.3,16506.15,15890.15,15943.1,15988.35,15982.9,16237.75,16318.2,16402.0,16486.95,16384.9,15991.6,15975.35,16004.5,16058.8,16036.05,16110.3,16253.2,16004.2,15957.45,16031.45,15808.35,15796.05,15885.15,15799.35,15624.6,15562.0,15552.4,15327.05,15159.9,15298.15,15512.0,15811.55,15864.75,15775.05,15897.8,15530.25,15504.55,15420.75,15303.7,15367.0,15595.55,15280.15,15096.2,15238.65,15344.55,15197.6,15297.65,15395.0,15354.15,15399.05,15398.6,15215.2,15291.1,15247.05,15293.05,15389.85,15399.35,15568.3,16087.55,16504.9,16379.2,16276.6,16096.25,16178.1,15848.25,15510.1,15777.35,15727.4,15697.7,15701.9,15628.4,15769.1,15746.0,15668.05,15605.7,15550.95,15435.95,15496.05,15483.15,15405.4,15001.55,15003.5,14996.05,14748.65,14601.7,14397.2,14487.8,14399.9,14546.65,14527.0,14576.05,14222.05,14299.5,14093.85,14432.1,14488.2,14477.75,14500.6,14634.8,14371.5,14434.55,14439.1,14448.95,14700.7,14651.55,14918.8,14716.3,14637.2,14471.3,14591.6,14352.55,14389.45,14497.75,14531.6,14613.9,14689.35,14754.8,14759.7,14687.55,14668.15,14616.25,14535.8,14771.8,14731.4,14484.8,14794.95,14646.5,14811.55,14852.8,14893.35,15029.5,15086.55,14983.3,14980.05,15160.15,15216.0,15314.55,14963.35,15233.55,15049.7,14959.9,14919.75,14964.85,14724.8,14839.9,15108.7,15076.35,15052.85,15202.6,15172.9,14997.25,15151.75,15169.2,15314.8,15403.45,15422.75,15850.4,16108.95,16205.0,16158.4,16110.0,16217.05,16053.85,16024.1,16019.9,16036.7,16165.65,16131.4,16049.45,15993.85,16102.3,16029.05,15958.15,15988.3,15964.7,15940.4,15897.95,15954.35,16076.95,16106.15,16327.3,16290.7,16461.2,16446.2,16526.45,16536.7,16573.65,16670.85,16427.6,16397.45,16471.4,16828.3,16537.35,16808.9,16736.35,16764.65,16809.75,17227.25,17260.6,17257.1,17250.2,17318.55,17400.45,17388.65,17336.45,17484.45,17344.25,17469.4,17529.65,17815.85,17859.85,17992.4,17935.15,18193.95,19012.75,19750.7,19266.75,18029.65,17925.15,17506.05,17507.35,18328.7,18290.8,18596.8,19010.55,18955.8,19045.3,18886.7,19074.4,18945.45,18925.3,18898.9,18906.65,19028.8,19137.8,19272.1,20028.8,19832.8,19850.8,19617.9,19711.55,19994.95,20706.9,21378.55,21454.05,21124.3,21004.1,20480.6,20559.3,20786.45,21464.95,21604.4,21204.95,21183.4,21010.8,19555.8,20517.8,22031.25,23108.85,23184.5,22100.1,21741.2,21796.9,22024.6,21705.85,21589.05,21551.55,21432.2,20573.75,20686.1,20992.0,20239.55,20049.8,20205.2,20607.7,20017.15,20049.4,19956.95,20308.35,20296.0,20295.05,20025.65,20071.7,20057.65,19990.45,19754.65,19950.5,19784.95,19664.9,19602.5,19512.1,19736.85,19167.4,19317.95,19581.2,19157.95,19087.25,18947.6,19004.9,18997.7,18711.7,18760.05,18932.45,18859.5,18660.2,18343.95,18273.75,18527.1,18439.95,18104.9,17917.25,17907.0,18219.75,18714.8,18423.45,18794.25,19050.65,19316.65,19381.95,19485.65,19285.1,18986.2,18866.35,18725.7,18372.9,18314.05,18169.4,17888.2,17809.9,17690.45,17515.4,17181.1,17018.3,16819.85,16980.85,16335.65,16718.9,16219.2,16083.2,16079.75,16140.15,16201.3,16083.35,15864.05,15775.35,15562.6,16672.4,16615.0,16537.05,16137.5,16464.8,16992.2,16762.3,16379.15,16292.3,16714.75,17021.25,16777.6,17379.8,17556.5,17200.25,17432.3,17459.4,17415.3,17705.85,17833.7,17496.7,17268.65,17041.45,17203.95,17322.4,17257.9,17251.9,16685.6,16642.05,16469.25,16021.85,16238.75,16909.95 ...

# %% [markdown]
# ## Data Preprocessing

# %%
pred_days = 45
timestep = 90

# %%
df = df[['Close']]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((0,1))

# df_train = df

# Test = 45 days
df_test = df[-pred_days:]
df_train = df[:-pred_days]
df_test.shape, df_train.shape

# Train-Val split (70-30)
trainSize = int(len(df_train) * 0.8)
df_val = df_train[trainSize:]
df_train = df_train[:trainSize]

# Create Train-Val 
train_set = df_train.values
val_set = df_val.values

train_set = scaler.fit_transform(np.array(train_set).reshape(-1,1))
val_set = scaler.fit_transform(np.array(val_set).reshape(-1,1))

def data_prep(dataset, timestep):
  X, y = [], []
  for i in range(timestep, dataset.shape[0]):
    X.append(dataset[i-timestep:i, 0])
    y.append(dataset[i,0])
  
  return (np.array(X), np.array(y))


(x_train, y_train) = data_prep(train_set, timestep)
(x_val, y_val) = data_prep(val_set, timestep)

x_train = np.reshape(x_train, newshape = (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, newshape = (x_val.shape[0], x_val.shape[1], 1))

  # return (x_train, y_train), (x_val, y_val), scaler

# %% [markdown]
# ## Define the model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import Huber

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(1))

opt = Adam(learning_rate = 0.001)
huber = Huber()
model.compile(optimizer = opt, loss=huber, metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 90, 50)            10400
#
#  dropout (Dropout)           (None, 90, 50)            0
#
#  lstm_1 (LSTM)               (None, 90, 50)            20200
#
#  dropout_1 (Dropout)         (None, 90, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
# Train the model
hist = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=2, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 12/12 - 11s - loss: 0.0368 - mae: 0.2027 - val_loss: 0.0275 - val_mae: 0.2233 - 11s/epoch - 877ms/step
# Epoch 2/100
# 12/12 - 2s - loss: 0.0078 - mae: 0.0948 - val_loss: 0.0268 - val_mae: 0.2192 - 2s/epoch - 136ms/step
# Epoch 3/100
# 12/12 - 2s - loss: 0.0058 - mae: 0.0838 - val_loss: 0.0383 - val_mae: 0.2655 - 2s/epoch - 169ms/step
# Epoch 4/100
# 12/12 - 3s - loss: 0.0045 - mae: 0.0718 - val_loss: 0.0255 - val_mae: 0.2081 - 3s/epoch - 247ms/step
# Epoch 5/100
# 12/12 - 2s - loss: 0.0044 - mae: 0.0723 - val_loss: 0.0212 - val_mae: 0.1846 - 2s/epoch - 192ms/step
# Epoch 6/100
# 12/12 - 2s - loss: 0.0041 - mae: 0.0666 - val_loss: 0.0187 - val_mae: 0.1705 - 2s/epoch - 136ms/step
# Epoch 7/100
# 12/12 - 2s - loss: 0.0040 - mae: 0.0673 - val_loss: 0.0222 - val_mae: 0.1887 - 2s/epoch - 134ms/step
# Epoch 8/100
# 12/12 - 2s - loss: 0.0043 - mae: 0.0699 - val_loss: 0.0254 - val_mae: 0.2045 - 2s/epoch - 138ms/step
# Epoch 9/100
# 12/12 - 2s - loss: 0.0040 - mae: 0.0664 - val_loss: 0.0295 - val_mae: 0.2241 - 2s/epoch - 135ms/step
# Epoch 10/100
# 12/12 - 2s - loss: 0.0039 - mae: 0.0649 - val_loss: 0.0184 - val_mae: 0.1636 - 2s/epoch - 136ms/step
# Epoch 11/100
# 12/12 - 2s - loss: 0.0036 - mae: 0.0632 - val_loss: 0.0144 - val_mae: 0.1294 - 2s/epoch - 160ms/step
# Epoch 12/100
# 12/12 - 2s - loss: 0.0036 - mae: 0.0641 - val_loss: 0.0119 - val_mae: 0.1065 - 2s/epoch - 207ms/step
# Epoch 13/100
# 12/12 - 2s - loss: 0.0034 - mae: 0.0622 - val_loss: 0.0145 - val_mae: 0.1279 - 2s/epoch - 134ms/step
# Epoch 14/100
# 12/12 - 2s - loss: 0.0030 - mae: 0.0586 - val_loss: 0.0213 - val_mae: 0.1760 - 2s/epoch - 137ms/step
# Epoch 15/100
# 12/12 - 2s - loss: 0.0036 - mae: 0.0631 - val_loss: 0.0163 - val_mae: 0.1402 - 2s/epoch - 135ms/step
# Epoch 16/100
# 12/12 - 2s - loss: 0.0031 - mae: 0.0605 - val_loss: 0.0153 - val_mae: 0.1305 - 2s/epoch - 135ms/step
# Epoch 17/100
# 12/12 - 2s - loss: 0.0035 - mae: 0.0626 - val_loss: 0.0153 - val_mae: 0.1337 - 2s/epoch - 134ms/step
# Epoch 18/100
# 12/12 - 2s - loss: 0.0030 - mae: 0.0581 - val_loss: 0.0147 - val_mae: 0.1288 - 2s/epoch - 144ms/step
# Epoch 19/100
# 12/12 - 3s - loss: 0.0033 - mae: 0.0603 - val_loss: 0.0125 - val_mae: 0.1096 - 3s/epoch - 268ms/step
# Epoch 20/100
# 12/12 - 2s - loss: 0.0033 - mae: 0.0596 - val_loss: 0.0117 - val_mae: 0.1064 - 2s/epoch - 186ms/step
# Epoch 21/100
# 12/12 - 2s - loss: 0.0030 - mae: 0.0567 - val_loss: 0.0104 - val_mae: 0.0982 - 2s/epoch - 135ms/step
# Epoch 22/100
# 12/12 - 2s - loss: 0.0036 - mae: 0.0634 - val_loss: 0.0093 - val_mae: 0.0971 - 2s/epoch - 136ms/step
# Epoch 23/100
# 12/12 - 2s - loss: 0.0034 - mae: 0.0614 - val_loss: 0.0096 - val_mae: 0.0983 - 2s/epoch - 135ms/step
# Epoch 24/100
# 12/12 - 2s - loss: 0.0032 - mae: 0.0570 - val_loss: 0.0122 - val_mae: 0.1088 - 2s/epoch - 136ms/step
# Epoch 25/100
# 12/12 - 2s - loss: 0.0028 - mae: 0.0558 - val_loss: 0.0109 - val_mae: 0.1019 - 2s/epoch - 195ms/step
# Epoch 26/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0542 - val_loss: 0.0142 - val_mae: 0.1229 - 2s/epoch - 173ms/step
# Epoch 27/100
# 12/12 - 2s - loss: 0.0029 - mae: 0.0590 - val_loss: 0.0178 - val_mae: 0.1478 - 2s/epoch - 136ms/step
# Epoch 28/100
# 12/12 - 2s - loss: 0.0028 - mae: 0.0557 - val_loss: 0.0173 - val_mae: 0.1455 - 2s/epoch - 136ms/step
# Epoch 29/100
# 12/12 - 2s - loss: 0.0034 - mae: 0.0589 - val_loss: 0.0160 - val_mae: 0.1373 - 2s/epoch - 187ms/step
# Epoch 30/100
# 12/12 - 2s - loss: 0.0029 - mae: 0.0574 - val_loss: 0.0157 - val_mae: 0.1363 - 2s/epoch - 179ms/step
# Epoch 31/100
# 12/12 - 2s - loss: 0.0028 - mae: 0.0545 - val_loss: 0.0115 - val_mae: 0.1073 - 2s/epoch - 150ms/step
# Epoch 32/100
# 12/12 - 3s - loss: 0.0025 - mae: 0.0528 - val_loss: 0.0120 - val_mae: 0.1135 - 3s/epoch - 214ms/step
# Epoch 33/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0530 - val_loss: 0.0128 - val_mae: 0.1177 - 2s/epoch - 137ms/step
# Epoch 34/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0542 - val_loss: 0.0126 - val_mae: 0.1164 - 2s/epoch - 134ms/step
# Epoch 35/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0541 - val_loss: 0.0142 - val_mae: 0.1281 - 2s/epoch - 135ms/step
# Epoch 36/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0493 - val_loss: 0.0105 - val_mae: 0.1037 - 2s/epoch - 137ms/step
# Epoch 37/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0519 - val_loss: 0.0112 - val_mae: 0.1069 - 2s/epoch - 134ms/step
# Epoch 38/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0519 - val_loss: 0.0119 - val_mae: 0.1154 - 2s/epoch - 134ms/step
# Epoch 39/100
# 12/12 - 3s - loss: 0.0024 - mae: 0.0502 - val_loss: 0.0118 - val_mae: 0.1132 - 3s/epoch - 223ms/step
# Epoch 40/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0545 - val_loss: 0.0096 - val_mae: 0.0998 - 2s/epoch - 139ms/step
# Epoch 41/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0530 - val_loss: 0.0101 - val_mae: 0.1026 - 2s/epoch - 136ms/step
# Epoch 42/100
# 12/12 - 2s - loss: 0.0027 - mae: 0.0529 - val_loss: 0.0113 - val_mae: 0.1104 - 2s/epoch - 135ms/step
# Epoch 43/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0514 - val_loss: 0.0110 - val_mae: 0.1082 - 2s/epoch - 136ms/step
# Epoch 44/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0514 - val_loss: 0.0118 - val_mae: 0.1155 - 2s/epoch - 134ms/step
# Epoch 45/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0485 - val_loss: 0.0088 - val_mae: 0.0987 - 2s/epoch - 135ms/step
# Epoch 46/100
# 12/12 - 3s - loss: 0.0023 - mae: 0.0511 - val_loss: 0.0096 - val_mae: 0.1014 - 3s/epoch - 209ms/step
# Epoch 47/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0515 - val_loss: 0.0100 - val_mae: 0.1058 - 2s/epoch - 153ms/step
# Epoch 48/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0512 - val_loss: 0.0116 - val_mae: 0.1184 - 2s/epoch - 136ms/step
# Epoch 49/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0510 - val_loss: 0.0145 - val_mae: 0.1401 - 2s/epoch - 136ms/step
# Epoch 50/100
# 12/12 - 2s - loss: 0.0026 - mae: 0.0530 - val_loss: 0.0130 - val_mae: 0.1314 - 2s/epoch - 134ms/step
# Epoch 51/100
# 12/12 - 2s - loss: 0.0025 - mae: 0.0500 - val_loss: 0.0124 - val_mae: 0.1263 - 2s/epoch - 135ms/step
# Epoch 52/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0499 - val_loss: 0.0089 - val_mae: 0.1000 - 2s/epoch - 133ms/step
# Epoch 53/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0470 - val_loss: 0.0098 - val_mae: 0.1090 - 2s/epoch - 188ms/step
# Epoch 54/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0481 - val_loss: 0.0100 - val_mae: 0.1104 - 2s/epoch - 176ms/step
# Epoch 55/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0513 - val_loss: 0.0074 - val_mae: 0.0927 - 2s/epoch - 135ms/step
# Epoch 56/100
# 12/12 - 3s - loss: 0.0024 - mae: 0.0501 - val_loss: 0.0086 - val_mae: 0.0989 - 3s/epoch - 243ms/step
# Epoch 57/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0463 - val_loss: 0.0087 - val_mae: 0.1013 - 2s/epoch - 135ms/step
# Epoch 58/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0486 - val_loss: 0.0090 - val_mae: 0.1021 - 2s/epoch - 134ms/step
# Epoch 59/100
# 12/12 - 3s - loss: 0.0023 - mae: 0.0479 - val_loss: 0.0095 - val_mae: 0.1097 - 3s/epoch - 210ms/step
# Epoch 60/100
# 12/12 - 3s - loss: 0.0023 - mae: 0.0481 - val_loss: 0.0111 - val_mae: 0.1219 - 3s/epoch - 244ms/step
# Epoch 61/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0509 - val_loss: 0.0123 - val_mae: 0.1299 - 2s/epoch - 152ms/step
# Epoch 62/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0467 - val_loss: 0.0089 - val_mae: 0.1067 - 2s/epoch - 135ms/step
# Epoch 63/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0481 - val_loss: 0.0077 - val_mae: 0.0948 - 2s/epoch - 134ms/step
# Epoch 64/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0471 - val_loss: 0.0074 - val_mae: 0.0927 - 2s/epoch - 139ms/step
# Epoch 65/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0458 - val_loss: 0.0085 - val_mae: 0.1041 - 2s/epoch - 135ms/step
# Epoch 66/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0463 - val_loss: 0.0072 - val_mae: 0.0911 - 2s/epoch - 139ms/step
# Epoch 67/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0470 - val_loss: 0.0100 - val_mae: 0.1159 - 2s/epoch - 199ms/step
# Epoch 68/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0474 - val_loss: 0.0079 - val_mae: 0.0983 - 2s/epoch - 168ms/step
# Epoch 69/100
# 12/12 - 2s - loss: 0.0019 - mae: 0.0450 - val_loss: 0.0092 - val_mae: 0.1113 - 2s/epoch - 137ms/step
# Epoch 70/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0462 - val_loss: 0.0105 - val_mae: 0.1219 - 2s/epoch - 140ms/step
# Epoch 71/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0491 - val_loss: 0.0118 - val_mae: 0.1302 - 2s/epoch - 136ms/step
# Epoch 72/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0479 - val_loss: 0.0099 - val_mae: 0.1170 - 2s/epoch - 138ms/step
# Epoch 73/100
# 12/12 - 2s - loss: 0.0024 - mae: 0.0496 - val_loss: 0.0112 - val_mae: 0.1250 - 2s/epoch - 136ms/step
# Epoch 74/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0475 - val_loss: 0.0092 - val_mae: 0.1103 - 2s/epoch - 193ms/step
# Epoch 75/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0464 - val_loss: 0.0084 - val_mae: 0.1052 - 2s/epoch - 176ms/step
# Epoch 76/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0460 - val_loss: 0.0093 - val_mae: 0.1121 - 2s/epoch - 139ms/step
# Epoch 77/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0473 - val_loss: 0.0099 - val_mae: 0.1167 - 2s/epoch - 140ms/step
# Epoch 78/100
# 12/12 - 2s - loss: 0.0019 - mae: 0.0456 - val_loss: 0.0084 - val_mae: 0.1044 - 2s/epoch - 136ms/step
# Epoch 79/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0476 - val_loss: 0.0091 - val_mae: 0.1107 - 2s/epoch - 136ms/step
# Epoch 80/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0469 - val_loss: 0.0068 - val_mae: 0.0895 - 2s/epoch - 137ms/step
# Epoch 81/100
# 12/12 - 2s - loss: 0.0019 - mae: 0.0451 - val_loss: 0.0057 - val_mae: 0.0815 - 2s/epoch - 188ms/step
# Epoch 82/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0460 - val_loss: 0.0079 - val_mae: 0.1016 - 2s/epoch - 182ms/step
# Epoch 83/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0455 - val_loss: 0.0088 - val_mae: 0.1093 - 2s/epoch - 136ms/step
# Epoch 84/100
# 12/12 - 2s - loss: 0.0018 - mae: 0.0443 - val_loss: 0.0060 - val_mae: 0.0829 - 2s/epoch - 136ms/step
# Epoch 85/100
# 12/12 - 2s - loss: 0.0019 - mae: 0.0447 - val_loss: 0.0071 - val_mae: 0.0951 - 2s/epoch - 137ms/step
# Epoch 86/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0457 - val_loss: 0.0059 - val_mae: 0.0834 - 2s/epoch - 135ms/step
# Epoch 87/100
# 12/12 - 2s - loss: 0.0018 - mae: 0.0434 - val_loss: 0.0071 - val_mae: 0.0955 - 2s/epoch - 137ms/step
# Epoch 88/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0452 - val_loss: 0.0055 - val_mae: 0.0808 - 2s/epoch - 192ms/step
# Epoch 89/100
# 12/12 - 3s - loss: 0.0020 - mae: 0.0467 - val_loss: 0.0053 - val_mae: 0.0808 - 3s/epoch - 277ms/step
# Epoch 90/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0445 - val_loss: 0.0056 - val_mae: 0.0817 - 2s/epoch - 162ms/step
# Epoch 91/100
# 12/12 - 2s - loss: 0.0022 - mae: 0.0462 - val_loss: 0.0068 - val_mae: 0.0918 - 2s/epoch - 139ms/step
# Epoch 92/100
# 12/12 - 2s - loss: 0.0018 - mae: 0.0445 - val_loss: 0.0060 - val_mae: 0.0852 - 2s/epoch - 138ms/step
# Epoch 93/100
# 12/12 - 2s - loss: 0.0020 - mae: 0.0445 - val_loss: 0.0075 - val_mae: 0.0991 - 2s/epoch - 142ms/step
# Epoch 94/100
# 12/12 - 2s - loss: 0.0018 - mae: 0.0423 - val_loss: 0.0078 - val_mae: 0.1014 - 2s/epoch - 141ms/step
# Epoch 95/100
# 12/12 - 2s - loss: 0.0017 - mae: 0.0422 - val_loss: 0.0072 - val_mae: 0.0967 - 2s/epoch - 136ms/step
# Epoch 96/100
# 12/12 - 3s - loss: 0.0017 - mae: 0.0412 - val_loss: 0.0063 - val_mae: 0.0870 - 3s/epoch - 217ms/step
# Epoch 97/100
# 12/12 - 2s - loss: 0.0018 - mae: 0.0435 - val_loss: 0.0072 - val_mae: 0.0958 - 2s/epoch - 155ms/step
# Epoch 98/100
# 12/12 - 2s - loss: 0.0021 - mae: 0.0465 - val_loss: 0.0103 - val_mae: 0.1218 - 2s/epoch - 136ms/step
# Epoch 99/100
# 12/12 - 2s - loss: 0.0023 - mae: 0.0483 - val_loss: 0.0072 - val_mae: 0.0966 - 2s/epoch - 138ms/step
# Epoch 100/100
# 12/12 - 2s - loss: 0.0017 - mae: 0.0406 - val_loss: 0.0058 - val_mae: 0.0821 - 2s/epoch - 137ms/step

# %%
plt.figure(figsize = (12, 8))
plt.plot(hist.history['loss'][2:], label = "Training loss")
plt.plot(hist.history['val_loss'][2:], label = "Val loss")
plt.title("Loss analysis")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid("both")

# %% [markdown]
# ## Model Evaluation

# %%
train_pred = model.predict(x_train)
val_pred = model.predict(x_val)

train_pred = scaler.inverse_transform(train_pred)
val_pred = scaler.inverse_transform(val_pred)

train_set_temp = scaler.inverse_transform(train_set)
val_set_temp = scaler.inverse_transform(val_set)
# Out:
# 12/12 [==============================] - 2s 37ms/step
# 1/1 [==============================] - 0s 58ms/step

# %%
x1 = train_set_temp[-(train_pred.shape[0]):]
plt.figure(figsize = (15,5))
plt.plot(x1, color = 'black', label = 'Real prices')
plt.plot(train_pred, color='red', label='Predicted prices')
plt.legend()
plt.grid()

# %%
x2 = val_set_temp[-(val_pred.shape[0]):]
plt.figure(figsize = (15,5))
plt.plot(x2, color = 'black', label = 'Real prices')
plt.plot(val_pred, color='red', label='Predicted prices')
plt.legend()
plt.grid()

# %% [markdown]
# ## Prediction

# %%
train_dataset = pd.concat([df_train, df_val])

train_values = train_dataset.values

# %%
def prediction(timestep, inp):
  input = inp[-(timestep+pred_days):]

  input = scaler.fit_transform(np.array(input).reshape(-1,1))

  x_test = []
  for i in range(timestep, input.shape[0]):
    x_test.append(input[(i - timestep) : i , 0])
  x_test = np.array(x_test)

  x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

  return x_test, scaler

# %%
x_test, scaler = prediction(timestep, train_values)
y_pred = model.predict(x_test)
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 2/2 [==============================] - 0s 38ms/step

# %%
plt.figure(figsize=(15,5))

plt.plot(df_test.values, color='black', label='Real Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.grid()
plt.legend()
plt.title(f"Stock Price Predicted for {comp_symbol}")
plt.xlabel("Next Days")
plt.ylabel("Price (Rs/Share)")
# Out:
# Text(0, 0.5, 'Price (Rs/Share)')
